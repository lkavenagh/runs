# %%
import os
import psycopg2
import datetime

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
sns.set()
sns.set_style("darkgrid")
sns.set_palette("Set1")

colors = sns.hls_palette(8, l=.3, s=.8)

# %matplotlib inline

km_in_a_mile = 1.60934

def readConfig(key):
    config = pd.read_table(r'c:\users\barby\documents\config.txt', header = None)
    config = [c.split('=') for c in config[0]]
    out = [c[1] for c in config if c[0] == key][0]
    return(out)

def dbGetQuery(q):
    pw = readConfig('pw')
    conn_string = "host='kavdb.c9lrodma91yx.us-west-2.rds.amazonaws.com' dbname='kavdb' user='lkavenagh' password='" + pw + "'"
    conn = psycopg2.connect(conn_string)
    conn.autocommit = True
    dat = pd.read_sql(q, conn)
    conn.close()
    return(dat)

# %%
dat = dbGetQuery('SELECT date, \
                        exercise, \
                        weight, \
                        sets, \
                        reps, \
                        rep_unit, \
                        reps * sets as total_reps, \
                        avg(reps) over (partition by date, exercise) as avg_reps, \
                        sum(sets * reps) over (partition by date, exercise) as sets_x_reps, \
                        sum(weight * reps * sets) over (partition by date, exercise) / sum(reps * sets) over (partition by date, exercise) as w_avg_weight, \
                        sum(weight * reps * sets) over (partition by date, exercise) as training_vol \
                    FROM workouts.workouts ORDER BY date')
dat = dat.sort_values('date')

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111)

exercises = list(set(dat.exercise))

for n,e in enumerate(exercises):
    this_dat = dat.loc[dat.exercise == e]
    if any(this_dat.rep_unit == 'rep'):
        ax.plot(this_dat.date, this_dat.w_avg_weight, label = e, color = colors[n], linewidth = 1, marker='o')
        #ax.text(max(this_dat.date), this_dat.weight.tail(1)), e, color = colors[n], fontweight = 'bold', fontsize = 14)

ax.legend(frameon = False, fontsize = 14, loc = 'lower center', bbox_to_anchor=(0.5, -0.3), ncol = 5)
for var in ['top', 'bottom', 'left', 'right']:
    ax.spines[var].set_visible(False)

ax.set_ylabel('Weight (lbs)')
xfmt = mdates.DateFormatter('%b %d')
ax.xaxis.set_major_formatter(xfmt)
ax.set_ylim(0,120);

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111)

exercises = list(set(dat.exercise))

for n,e in enumerate(exercises):
    this_dat = dat.loc[dat.exercise == e]
    if any(this_dat.rep_unit == 'rep'):
        ax.plot(this_dat.date, this_dat.training_vol, label = e, color = colors[n], linewidth = 1, marker='o')
        #ax.text(max(this_dat.date), this_dat.weight.tail(1)), e, color = colors[n], fontweight = 'bold', fontsize = 14)

ax.legend(frameon = False, fontsize = 14, loc = 'lower center', bbox_to_anchor=(0.5, -0.3), ncol = 5)
for var in ['top', 'bottom', 'left', 'right']:
    ax.spines[var].set_visible(False)
    
ax.set_ylabel('Training volume (sets x reps x weight)')
xfmt = mdates.DateFormatter('%b %d')
ax.xaxis.set_major_formatter(xfmt);

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111)

this_dat = dat.groupby('date', as_index = False).sum()[['date', 'training_vol']]
this_dat = this_dat.loc[this_dat.training_vol > 0]
ax.plot(this_dat.date, this_dat.training_vol, color = colors[n], linewidth = 1, marker='o')

for var in ['top', 'bottom', 'left', 'right']:
    ax.spines[var].set_visible(False)
    
ax.set_ylabel('TOTAL training volume (sets x reps x weight)')
xfmt = mdates.DateFormatter('%b %d')
ax.xaxis.set_major_formatter(xfmt);

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111)

exercises = list(set(dat.exercise))

for n,e in enumerate(exercises):
    this_dat = dat.loc[dat.exercise == e]
    if any(this_dat.rep_unit == 'sec'):
        ax.plot(this_dat.date, this_dat.avg_reps, label = e, color = colors[n], linewidth = 1, marker='o')
        #ax.text(max(this_dat.date), this_dat.weight.tail(1)), e, color = colors[n], fontweight = 'bold', fontsize = 14)

ax.legend(frameon = False, fontsize = 14, loc = 'lower center', bbox_to_anchor=(0.5, -0.3), ncol = 5)
for var in ['top', 'bottom', 'left', 'right']:
    ax.spines[var].set_visible(False)
    
xfmt = mdates.DateFormatter('%b %d')
ax.xaxis.set_major_formatter(xfmt)
ax.set_ylabel('Average length of set (secs)')
ax.set_ylim(0,120);

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.add_subplot(111)

exercises = list(set(dat.exercise))

for n,e in enumerate(exercises):
    this_dat = dat.loc[dat.exercise == e]
    if any(this_dat.rep_unit == 'sec'):
        ax.plot(this_dat.date, this_dat.sets_x_reps, label = e, color = colors[n], linewidth = 1, marker='o')
        #ax.text(max(this_dat.date), this_dat.weight.tail(1)), e, color = colors[n], fontweight = 'bold', fontsize = 14)

ax.legend(frameon = False, fontsize = 14, loc = 'lower center', bbox_to_anchor=(0.5, -0.3), ncol = 5)
for var in ['top', 'bottom', 'left', 'right']:
    ax.spines[var].set_visible(False)
    
xfmt = mdates.DateFormatter('%b %d')
ax.xaxis.set_major_formatter(xfmt)
ax.set_ylabel('Total time spent on exercise (secs)')
ax.set_ylim(0,120);
